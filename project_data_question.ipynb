# %% [markdown]
# # Assignment Directions
#
# In a code cell below this one, pull your data into a dataframe.
#
# In a markdown cell, the student should explain the dataset they have chosen and the question they are trying to answer. Why do you think this dataset is interesting? What do you hope to learn from it? What are your goals?

# %%
import kagglehub
path = kagglehub.dataset_download("tobycrabtree/nfl-scores-and-betting-data")

# Validate that the file was downloaded
print("Path to dataset files:", path)

import kagglehub
from kagglehub import KaggleDatasetAdapter

file_path = "spreadspoke_scores.csv"

# Pull the data into a dataframe
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "tobycrabtree/nfl-scores-and-betting-data",
  file_path,
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

# Print the dataset to get a feel for the data
df
# Out:
# ...
# 100%|██████████| 246k/246k [00:00<00:00, 47.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/tobycrabtree/nfl-scores-and-betting-data/versions/66
# <ipython-input-1-f20fc577876a>:12: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df = kagglehub.load_dataset(
# Download already complete (1544250 bytes).
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 14081     1/19/2025             2024      Division              True
# ...

# %% [markdown]
# I have chosen to use the "NFL Scores and Betting Data" dataset for my project. I think the dataset is interesting because I'm an NFL football fan and my favorite team is the Pittsburgh Steelers.  I'd like to learn if there really is such a thing as a home field advantage, and whether the total points scored was typically over or under the over_under_line.  My goal is to see if it's worth betting on the home team to win, and/or whether it's worth betting on the total points being over/under the line.
